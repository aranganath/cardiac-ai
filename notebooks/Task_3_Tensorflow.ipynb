# %% [markdown]
# # Getting started with Task 3

# %% [markdown]
# Download the dataset from the [Dataset of Simulated Intracardiac Transmembrane Voltage Recordings and ECG Signals](https://library.ucsd.edu/dc/object/bb29449106) using the script `download_intracardiac_dataset.sh`:
#
# ```bash
# source download_intracardiac_dataset.sh
# ```

# %% [markdown]
# ## Load Modules and Preprocessing Functions

# %% [markdown]
# Load modules and preprocessing functions.

# %%
import glob, re, os
import numpy as np
import matplotlib.pyplot as plt
from typing import List

# %% [markdown]
# Load the `cardiac_ml_tools` module.

# %%
# %run cardiac_ml_tools.py

# %% [markdown]
# ## Load the dataset

# %%
data_dirs = []
regex = r'data_hearts_dd_0p2*'
DIR= '../Datasets/intracardiac_dataset/' # This should be the path to the intracardiac_dataset, it can be downloaded using data_science_challenge_2023/download_intracardiac_dataset.sh
for x in os.listdir(DIR):
    if re.match(regex, x):
        data_dirs.append(DIR + x)
file_pairs = read_data_dirs(data_dirs)
print('Number of file pairs: {}'.format(len(file_pairs)))
# example of file pair
print("Example of file pair:")
print("{}\n{}".format(file_pairs[0][0], file_pairs[0][1]))
# Out:
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Automatic sorted not matching, looking for pairs ...done.
# Number of file pairs: 16116
# Example of file pair:
# ../Datasets/intracardiac_dataset/data_hearts_dd_0p2\pECGData_hearts_dd_0p2_volunteer.v10_pattern.1.npy
# ../Datasets/intracardiac_dataset/data_hearts_dd_0p2\VmData_hearts_dd_0p2_volunteer.v10_pattern.1.npy

# %% [markdown]
# ## Dataset details

# %% [markdown]
# The dataset [Dataset of Simulated Intracardiac Transmembrane Voltage Recordings and ECG Signals](https://library.ucsd.edu/dc/object/bb29449106)
# consists of pairs of computationally simulated intracardiac transmembrane voltage recordings and ECG signals.
# In total, 16140 organ-level simulations were conducted to create this dataset.
# Simulations were performed using Lassen supercomputer at Lawrence Livermore National Lab (LLNL), concurrently utilizing 4 GPUs and 40 CPU cores.
# Each simulation produced pairs of 500ms-by-10 raw electrode signals and 500ms-by-75 transmembrane voltage signals.
# For convenience, we collect those signals in matrices and give them the following names:
#
# Tensor | Description | Shape | Notes
# --- | --- | --- | ---
# $X$ | Row electrode signals | $10 \times 500$ | 10-lead ECG signals from the simulated torso (in [Dataset of Simulated Intracardiac Transmembrane Voltage Recordings and ECG Signals](https://library.ucsd.edu/dc/object/bb29449106))
# $V$ | Activation map | $75 \times 500$ | Transmembrane voltage signals from the simulated heart (in [Dataset of Simulated Intracardiac Transmembrane Voltage Recordings and ECG Signals](https://library.ucsd.edu/dc/object/bb29449106))
# $E$ | 12-lead ECG signals | $12 \times 500$ | 12-lead ECG signals obtained by `get_standard_leads`($X$)
# $A$ | Activation map | $75 \times 1$ | Activation time, defined as $A_i = \text{min}_j(V_{ij})$
#
# **IMPORTANT** : The raw data in the dataset consists of 10-lead ECG signals and 75-lead transmembrane voltage signals. The 12-lead ECG signals are obtained from the 10-lead ECG signals using the function `get_standard_leads` (in the file `cardiac_ml_tools.py`).
#
# The overall generation process is shown in the following image. The ECG signal is recorded using 10 virtual electrodes and the transmembrane voltages are recorded at 75 points within the myocardium. The transmembrane voltages are then used to generate the spatio-temporal activation maps.

# %% [markdown]
# ![ECG 10 2 12](../figures/data_generation.png)

# %% [markdown]
# ## Getting the standard 12-lead ECG from the 10-lead ECG
#
# The function `get_standard_leads` (in the file `cardiac_ml_tools.py`) is used to obtain the 12-lead ECG signals from the 10-lead ECG signals. It implements the following transformation, where the (Wilson Lead) is defined as $Vw = 1/3*(RA + LA + LL)$:
# $$
# \left\{
# \begin{array}{lll}
#     X_{:,1}  & \to  & RA \\
#     X_{:,2}  & \to  & LA \\
#     X_{:,3}  & \to  & LL \\
#     X_{:,4}  & \to  & RL \\
#     X_{:,5}  & \to  & V1 \\
#     X_{:,6}  & \to  & V2 \\
#     X_{:,7}  & \to  & V3 \\
#     X_{:,8}  & \to  & V4 \\
#     X_{:,9}  & \to  & V5 \\
#     X_{:,10} & \to &  V6 \\
# \end{array}
# \right.
# \text{        and        }
# \left\{
# \begin{array}{lll}
# \text{Lead } I& : & LA - RA \\
# \text{Lead } II& : & LL - RA \\
# \text{Lead } III& : & LL - LA \\
# \text{Lead } aVR& : &  \frac{3}{2} (RA - Vw) \\
# \text{Lead } aVL& : &  \frac{3}{2} (LA - Vw) \\
# \text{Lead } aVF& : &  \frac{3}{2} (LL - Vw)\\
# \text{Lead } V1 & : & V1 - Vw \\
# \text{Lead } V2 & : & V2 - Vw \\
# \text{Lead } V3 & : & V3 - Vw \\
# \text{Lead } V4 & : & V4 - Vw \\
# \text{Lead } V5 & : & V5 - Vw \\
# \text{Lead } V6 & : & V6 - Vw \\
# \end{array}
# \right.
# $$

# %%
# Example of file pair
case = 213
# ECG plot
row = 3 
column = 4
num_timesteps = 500
plt.figure(figsize=(10, 7))
titles = ["I", "II", "III", "aVR", "aVL", "aVF", "V1", "V2", "V3", "V4", "V5", "V6"]
reorder = {1:1,2:5,3:9,4:2,5:6,6:10,7:3,8:7,9:11,10:4,11:8,12:12} # reorder the leads to standard 12-lead ECG display

print('Case {} : {}'.format(case, file_pairs[case][0]))
pECGData = np.load(file_pairs[case][0])
pECGData = get_standard_leads(pECGData)

# create a figure with 12 subplots
for i in range(pECGData.shape[1]):
    plt.subplot(row, column, reorder[i + 1])
    plt.plot(pECGData[0:num_timesteps,i],'r')
    plt.title(titles[i])
    plt.grid(visible=True, which='major', color='#666666', linestyle='-')
    plt.minorticks_on()
    plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
    plt.xlabel('msec')
    plt.ylabel('mV')
plt.tight_layout()
plt.show()
# close
plt.close()
# Out:
# Case 213 : ../Datasets/intracardiac_dataset/data_hearts_dd_0p2\pECGData_hearts_dd_0p2_volunteer.v1_pattern.19.npy

# %% [markdown]
# ## Getting the activation map from the transmembrane voltages
#
# The funtion `get_activation_map` (in the file `cardiac_ml_tools.py`) is used to obtain the activation map from the transmembrane voltages. It implements the following transformation $A_i = \text{min}_j(V_{ij})$.

# %%
# Example of file pair
case = 213
plt.figure(figsize=(1, 10))

print('Case {} : {}'.format(case, file_pairs[case][0]))
VmData = np.load(file_pairs[case][1])

ActTime = get_activation_time(VmData)

# plot the Activation Time array
plt.imshow(ActTime, cmap='jet', interpolation='nearest', aspect='auto')
plt.title('Activation Time')
plt.colorbar()
plt.grid(visible=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
# not xticks
plt.xticks([])
plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.show()
# Out:
# Case 213 : ../Datasets/intracardiac_dataset/data_hearts_dd_0p2\pECGData_hearts_dd_0p2_volunteer.v1_pattern.19.npy

# %% [markdown]
# ## Task 3: Learning the mapping from the 12-lead ECG to the activation map

# %%
# make a plot with the "pECGData" -> "ActTime"
case = 213

print('Case {} : {}'.format(case, file_pairs[case][0]))
pECGData = np.load(file_pairs[case][0])
pECGData = get_standard_leads(pECGData)

print('Case {} : {}'.format(case, file_pairs[case][0]))
VmData = np.load(file_pairs[case][1])
ActTime = get_activation_time(VmData)

# plot in row the tensors pECGData and ActTime with an arrow pointing to the activation time
row = 1
column = 3
plt.figure(figsize=(20, 5))
plt.subplot(row, column, 1)
# plot pECGData transposed
plt.imshow(pECGData.T, cmap='jet', interpolation='nearest', aspect='auto')
plt.title('pECGData')
plt.subplot(row, column, 2)
# print an arrow
plt.text(0.5, 0.5, '-------->', horizontalalignment='center', verticalalignment='center', fontsize=20)
plt.axis('off')
plt.subplot(row, column, 3)
# plot ActTime
plt.imshow(ActTime, cmap='jet', interpolation='nearest', aspect='auto')
# not xticks
plt.xticks([])
plt.title('ActTime')
plt.show()
plt.close()
# Out:
# Case 213 : ../Datasets/intracardiac_dataset/data_hearts_dd_0p2\pECGData_hearts_dd_0p2_volunteer.v1_pattern.19.npy
# Case 213 : ../Datasets/intracardiac_dataset/data_hearts_dd_0p2\pECGData_hearts_dd_0p2_volunteer.v1_pattern.19.npy

# %% [markdown]
# # Tricks
#
# - As in many machine learning problems, normalization of the data might be helpful or even necessary. Different normalization schemes might be applied.

# %%
import tensorflow as tf

# %%
VmData.shape, pECGData.shape, ActTime.shape
# Out:
# ((500, 75), (500, 12), (75, 1))

# %%
def network_model(input_shape, time_steps, features ):
    # Define the model architecture
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=input_shape),
        tf.keras.layers.Conv1D(filters=64, kernel_size=3, strides=1, padding='same'),
        tf.keras.layers.MaxPooling1D(pool_size=3, strides=1, padding='same'),
        
        # Fire Module 1
        tf.keras.layers.Conv1D(filters=16, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(64, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=16, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(64, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=16, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(64, activation='relu'),
        
        # Fire Module 2
        tf.keras.layers.Conv1D(filters=16, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(64, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=16, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(64, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=16, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(64, activation='relu'),
        
        # Layer 2
        tf.keras.layers.MaxPooling1D(pool_size=3, strides=1, padding='same'),
        
        # Fire Module 3
        tf.keras.layers.Conv1D(filters=32, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(128, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=32, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(128, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=32, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(128, activation='relu'),
        
        # Fire Module 4
        tf.keras.layers.Conv1D(filters=32, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(128, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=32, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(128, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=32, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(128, activation='relu'),
        
        # Layer 3
        tf.keras.layers.MaxPooling1D(pool_size=3, strides=1, padding='same'),
        
        # Fire Module 5
        tf.keras.layers.Conv1D(filters=48, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(192, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=48, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(192, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=48, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(192, activation='relu'),
        
        # Fire Module 6
        tf.keras.layers.Conv1D(filters=48, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(192, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=48, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(192, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=48, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(192, activation='relu'),
        
        # Fire Module 7
        tf.keras.layers.Conv1D(filters=64, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(256, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=64, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(256, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=64, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(256, activation='relu'),
        
        # Fire Module 8
        tf.keras.layers.Conv1D(filters=64, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(256, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=64, kernel_size=1, strides=1, padding='same'),
        tf.keras.layers.Dense(256, activation='relu'),
        
        tf.keras.layers.Conv1D(filters=64, kernel_size=1, strides=3, padding='same'),
        tf.keras.layers.Dense(256, activation='relu'),
        
        # Last Layer
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Conv1D(filters=75, kernel_size=1, padding='valid'),
    ])

    # Compile the model
    model.compile(
        loss=tf.keras.losses.MeanSquaredError(),
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=['accuracy']
    )

    return model

time_steps = 500
features = 1
input_shape = (time_steps, features)

model = network_model(input_shape, time_steps, features)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 500, 64)           256
#
#  max_pooling1d (MaxPooling1D  (None, 500, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 500, 16)           1040
#
#  dense (Dense)               (None, 500, 64)           1088
#
#  conv1d_2 (Conv1D)           (None, 500, 16)           1040
#
#  dense_1 (Dense)             (None, 500, 64)           1088
#
#  conv1d_3 (Conv1D)           (None, 167, 16)           1040
#
#  dense_2 (Dense)             (None, 167, 64)           1088
#
#  conv1d_4 (Conv1D)           (None, 167, 16)           1040
#
#  dense_3 (Dense)             (None, 167, 64)           1088
#
#  conv1d_5 (Conv1D)           (None, 167, 16)           1040
#
#  dense_4 (Dense)             (None, 167, 64)           1088
#
#  conv1d_6 (Conv1D)           (None, 56, 16)            1040
#
#  dense_5 (Dense)             (None, 56, 64)            1088
#
#  max_pooling1d_1 (MaxPooling  (None, 56, 64)           0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 56, 32)            2080
#
#  dense_6 (Dense)             (None, 56, 128)           4224
#
#  conv1d_8 (Conv1D)           (None, 56, 32)            4128
#
#  dense_7 (Dense)             (None, 56, 128)           4224
#
#  conv1d_9 (Conv1D)           (None, 19, 32)            4128
#
#  dense_8 (Dense)             (None, 19, 128)           4224
#
#  conv1d_10 (Conv1D)          (None, 19, 32)            4128
#
#  dense_9 (Dense)             (None, 19, 128)           4224
#
#  conv1d_11 (Conv1D)          (None, 19, 32)            4128
#
#  dense_10 (Dense)            (None, 19, 128)           4224
#
#  conv1d_12 (Conv1D)          (None, 7, 32)             4128
#
#  dense_11 (Dense)            (None, 7, 128)            4224
#
#  max_pooling1d_2 (MaxPooling  (None, 7, 128)           0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 7, 48)             6192
#
#  dense_12 (Dense)            (None, 7, 192)            9408
#
#  conv1d_14 (Conv1D)          (None, 7, 48)             9264
#
#  dense_13 (Dense)            (None, 7, 192)            9408
#
#  conv1d_15 (Conv1D)          (None, 3, 48)             9264
#
#  dense_14 (Dense)            (None, 3, 192)            9408
#
#  conv1d_16 (Conv1D)          (None, 3, 48)             9264
#
#  dense_15 (Dense)            (None, 3, 192)            9408
#
#  conv1d_17 (Conv1D)          (None, 3, 48)             9264
#
#  dense_16 (Dense)            (None, 3, 192)            9408
#
#  conv1d_18 (Conv1D)          (None, 1, 48)             9264
#
#  dense_17 (Dense)            (None, 1, 192)            9408
#
#  conv1d_19 (Conv1D)          (None, 1, 64)             12352
#
#  dense_18 (Dense)            (None, 1, 256)            16640
#
#  conv1d_20 (Conv1D)          (None, 1, 64)             16448
#
#  dense_19 (Dense)            (None, 1, 256)            16640
#
#  conv1d_21 (Conv1D)          (None, 1, 64)             16448
#
#  dense_20 (Dense)            (None, 1, 256)            16640
#
#  conv1d_22 (Conv1D)          (None, 1, 64)             16448
#
#  dense_21 (Dense)            (None, 1, 256)            16640
#
#  conv1d_23 (Conv1D)          (None, 1, 64)             16448
#
#  dense_22 (Dense)            (None, 1, 256)            16640
#
#  conv1d_24 (Conv1D)          (None, 1, 64)             16448
#
#  dense_23 (Dense)            (None, 1, 256)            16640
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  conv1d_25 (Conv1D)          (None, 1, 75)             19275
#
# =================================================================
# Total params: 383,755
# Trainable params: 383,755
# Non-trainable params: 0
# _________________________________________________________________
